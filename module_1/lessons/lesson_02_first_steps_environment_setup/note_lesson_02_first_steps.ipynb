# %% [markdown]
# # Урок 2 — Перші кроки та мінімальна робоча програма (+ налаштування середовища)
#
# > За 2 години: встановлюєш Python, запускаєш перший код у двох режимах (REPL і скрипт),
# > керуєш тим, що саме друкує `print()`, і читаєш свою першу помилку без паніки.

# %% [markdown]
# ## Перед початком — розумієш середовище?
#
# Цей урок спирається на ментальну модель Python (interpreter / pip / venv / IDE / notebook).
# Якщо ще не читав(-ла) — почни звідси, тут лише 5 концептів:
#
# 👉 [`docs/00_python_mental_model.md`](../../../docs/00_python_mental_model.md)
#
# Якщо коротко: **Activate environment → Install packages → Run code** — golden rule, до якого ми ще не раз повернемось.

# %% [markdown]
# ## 1. Як Python виконує код
#
# Коли ти пишеш файл `script.py` і запускаєш його, відбувається не "магія", а конкретний процес:
#
# ```
# джерельний код (.py) → байткод → віртуальна машина Python
# ```
#
# Python читає твій файл, перекладає його у проміжну форму (**байткод**) і виконує цю форму на віртуальній машині. Це причина, чому поруч зі скриптом іноді з'являється папка `__pycache__` — там Python кешує байткод.
#
# ### "Interpreted" чи "compiled"?
#
# Python зазвичай називають **інтерпретованою мовою** — не тому, що компіляції немає (вона є, у байткод), а тому що ти запускаєш програму просто з джерельного файлу, без окремого кроку "спочатку скомпілювати в exe". Правильніше думати про це не як про бінарний вибір, а як про спектр: швидкість зворотного зв'язку проти швидкості виконання.

# %%
# Запусти цю клітинку — і подивись у файловому провіднику поруч із ноутбуком:
# після першого запуску Python-скрипта в цій же папці зазвичай з'являється __pycache__/
# (у Jupyter це не завжди видно так само явно, як при запуску .py з терміналу — про це нижче)

import sys
print("Python версія:", sys.version)

# %% [markdown]
# ## 2. Два режими роботи: REPL і скрипт
#
# ### REPL (Read-Eval-Print Loop)
#
# Коли ти запускаєш `python3` (або `py` на Windows) без файлу — відкривається інтерактивний режим із запрошенням `>>>`. Кожен рядок виконується **одразу**, і Python сам показує результат.
#
# ```
# >>> 2 + 2
# 4
# >>> "hello"
# 'hello'
# ```
#
# Вийти: `exit()`, або `Ctrl+D` (macOS/Linux) / `Ctrl+Z` потім `Enter` (Windows).
#
# ### Скрипт (.py файл)
#
# Файл виконується **цілком, згори донизу**, і **нічого не друкує сама по собі** — доки ти явно не викличеш `print()`.
#
# ### 🔮 Передбач перед тим, як прочитаєш відповідь
#
# Уяви два сценарії з тим самим кодом `2 + 2`:
#
# 1. Ти вводиш `2 + 2` у REPL і тиснеш Enter.
# 2. Ти зберігаєш рядок `2 + 2` (і більше нічого) у файл `silent.py` і запускаєш `python3 silent.py` у терміналі.
#
# **Що з'явиться на екрані в кожному випадку?** Запиши свою відповідь — і лише тоді читай далі.
#
# <details>
# <summary>Відповідь (розгорни після того, як запишеш свою)</summary>
#
# 1. REPL надрукує <code>4</code> — REPL автоматично показує (echo) значення кожного виразу.<br>
# 2. Скрипт <b>нічого не надрукує</b> — файл обчислює <code>2 + 2</code>, але результат нікуди не виводиться, бо немає <code>print()</code>. Це і є найчастіша пастка перших тижнів: «мій код зламався», хоча насправді він просто мовчить.
#
# </details>

# %% [markdown]
# ## 3. `print()`, `sep`, `end`, `\n`, `\t`
#
# `print()` приймає кілька аргументів і два іменовані параметри, які керують тим, як саме вони з'являються на екрані:
#
# - `sep` — що ставити **між** аргументами (за замовчуванням — пробіл);
# - `end` — що ставити **в кінці** виклику (за замовчуванням — перехід на новий рядок `\n`).
#
# Escape-послідовності всередині рядка:
#
# - `\n` — новий рядок;
# - `\t` — символ табуляції (вирівнює до наступної позиції, кратної 8, а не просто «додає 4 пробіли» — це важливо в домашньому завданні).

# %%
print("one", "two", "three")                 # sep за замовчуванням — пробіл
print("one", "two", sep=", ")                 # sep замінює пробіл між аргументами
print("one", "two", end="...")                # end замінює перехід на новий рядок
print()                                        # порожній print — просто переносить рядок
print("A\tB")                                  # таб між A і B
print("A\nB")                                  # новий рядок між A і B

# %% [markdown]
# ### 🔮 Передбач і перевір — 4 раунди
#
# Перед тим як запускати кожен рядок нижче, запиши (усно чи в коментарі), що саме буде надруковано:
#
# 1. `print("one", "two", "three")`
# 2. `print("one", "two", sep="->")`
# 3. `print("one", "two", end="...")`
# 4. Порівняй `"A\tB"` і `"A\nB"` — чим відрізняється результат?
#
# Потім запусти клітинку вище ще раз і звір із власним прогнозом.

# %% [markdown]
# ## 4. Коментарі (`#`)
#
# Рядок, що починається з `#` (або частина рядка після `#`), Python повністю ігнорує — це коментар для людей, не для інтерпретатора.

# %%
# Це коментар — Python його не виконує
print("Це виконається")  # а це виконається, коментар після коду теж ігнорується
# print("А це — ні, весь рядок закоментовано")

# %% [markdown]
# ## 5. Отримати допомогу, не виходячи з термінала
#
# `help()` — вбудована довідка. У Jupyter є ще швидший спосіб: постав `?` після імені (наприклад, `print?`), і в новому вікні з'явиться довідка.

# %%
help(print)

# %% [markdown]
# ## 6. Прочитати першу помилку без паніки
#
# `SyntaxError` означає, що Python не зміг навіть **прочитати** твій код — не те що виконати. Повідомлення показує файл, рядок і стрілку біля проблемного місця.
#
# Приклад (навмисно зламаний рядок — розкоментуй і запусти, щоб побачити повідомлення):

# %%
# print("Незакритий рядок

# %% [markdown]
# ---
# # Самоперевірка (9 запитань)
#
# Спробуй відповісти сам(-а) перед тим, як дивитись позначену відповідь (✔).
#
# **1.** Що надрукується при запуску `print("Hello world!")`?
# a) `Hello world!` ✔ · b) `"Hello world!"` з лапками · c) Нічого · d) `print("Hello world!")`
#
# **2.** Який рядок коректно друкує повідомлення в Python 3?
# a) `print "текст"` · b) `print("текст")` ✔ · c) `"текст"` · d) `("текст")`
#
# **3.** Що Python робить із джерельним кодом перед виконанням?
# a) Перекладає у файл машинного коду, який запускається окремо · b) Компілює в байткод і виконує його на віртуальній машині ✔ · c) Надсилає кожен рядок прямо на процесор · d) Нічого — `.py`-файл вже машинний код
#
# **4.** Python зазвичай називають інтерпретованою мовою, хоча він компілює в байткод. Чому?
# a) Бо ти запускаєш програму прямо з джерельного файлу, без окремого кроку компіляції ✔ · b) Бо в Python взагалі немає компілятора · c) Бо байткод — це те саме, що машинний код · d) Бо Python-програми працюють швидше за скомпільовані
#
# **5.** У тебе є файл `script.py`. Як його запустити з термінала?
# a) `run script.py` · b) `python run script.py` · c) `script.py run` · d) `python script.py` ✔
#
# **6.** Яке розширення файлу правильне для Python?
# a) `.p` · b) `.py` ✔ · c) `.python` · d) `.pyt`
#
# **7.** Що надрукує `print("one", "two", sep=", ", end="...")`?
# a) `one two...` · b) `one, two...` ✔ · c) `one, two` · d) `"one", "two"...`
#
# **8.** Який виклик друкує рівно два рядки — спочатку `A`, потім `B`?
# a) `print("A\tB")` · b) `print("A\nB")` ✔ · c) `print("A", "B")` · d) `print("A" "B")`
#
# **9.** Що Python робить із рядком `# print("Hello")`?
# a) Друкує `Hello` · b) Друкує `# print("Hello")` · c) Нічого — усе після `#` у цьому рядку коментар ✔ · d) Викликає `SyntaxError`

# %% [markdown]
# ---
# # 📚 Домашнє завдання
#
# Нагадування про AI-політику курсу (з Уроку 1): AI-асистент — співрозробник, не заміна. У кожному файлі, який здаєш, додай рядок `# AI log: ...` — що саме питав(-ла) в AI і що написав(-ла) сам(-а). Якщо не використовував(-ла) — `# AI log: none`.
#
# Найважливіше правило цих двох завдань: **спочатку прогноз, потім запуск**. Якщо вставиш готовий код без прогнозу — саме цей крок і пропустиш, а він тут головний.

# %% [markdown]
# ## Завдання 3 — `task3.py`: дві літери з `#`
#
# Напиши програму з **двома** викликами `print()`, які малюють великі літери **O** та **H** символами `#`.
# Кожна фігура — 5 рядків заввишки і 9 символів завширшки:
#
# ```
# O:            H:
# #########     #       #
# #       #     #       #
# #       #     #########
# #       #     #       #
# #########     #       #
# ```
#
# **Правила:**
# - Пробіли заборонені — розриви роби через `\t`.
# - Заборонено будувати всю картинку одним потрійним """ блоком — використовуй `\n` і `\t`.
# - Таб при перевірці рахується як **8 символів**. У твоєму редакторі `\t` може виглядати як 4 — це лише налаштування відображення, не реальна ширина. `# + \t + #` дає рівно 9 символів.
# - Слідкуй за зайвими `\t` і `\n` — вони невидимі при звичайному перегляді; виділи вивід мишкою, щоб їх побачити.
#
# **Час:** 20–30 хв. **AI-стійкий елемент:** перед запуском файлу додай коментар, скільки символів завширшки буде кожен рядок і чому.

# %%
# task3.py — дві літери з #

# AI log: none

# BEGIN SOLUTION
print("#########\n#\t#\n#\t#\n#\t#\n#########")   # O
print("#\t#\n#\t#\n#########\n#\t#\n#\t#")           # H
# END SOLUTION

# %% [markdown]
# ## Завдання 5 — твоя власна візитівка
#
# Напиши програму, яка друкує маленьку "візитівку" про тебе: ім'я, місто і одну причину, чому почав(-ла) цей курс.
#
# **Умови:**
# - використай `sep` хоча б один раз і `end` хоча б один раз;
# - використай `\n` або `\t`, щоб вирівняти вивід;
# - жодного нового синтаксису — лише те, що вже було на цьому уроці. Без змінних, без `if`, без циклів — вони будуть на уроках 3 і 4;
# - останній рядок виводу — розділювач, який придумаєш сам(-а) (наприклад, ряд `-` або `=`).
#
# Приклад формату (не копіюй дослівно — заповни своїми даними): `Анна | Львів | Python`
#
# **Час:** 15–20 хв. **AI-стійкий елемент:** вміст — твій; асистент не знає твого міста чи причини. Будь готов(-а) за 30 секунд на наступному занятті сказати, який параметр дав яку частину виводу.

# %%
# task5.py — твоя візитівка

# AI log: none

# BEGIN SOLUTION
print("Ольга", "Львів", "Python", sep=" | ", end="\n")
print("Причина: хочу автоматизувати рутинні задачі на роботі.")
print("====================")
# END SOLUTION

# %% [markdown]
# ## Далі
#
# Перед Уроком 3 перевір: чи можеш ти, не заглядаючи в конспект, запустити скрипт із термінала (`python3 task3.py`)? Якщо ні — це і є домашнє завдання номер один, усе інше чекає.
#
# Урок 3 — Змінні та примітивні типи даних: сьогоднішній REPL стане пісочницею для змінних, а `print()` — способом зазирнути всередину змінної.
