# %% [markdown]
# <a href="https://colab.research.google.com/github/NikoriakViktot/PY-Course-Victor-Nikoriak-22-09-2026/blob/main/module_1/lessons/lesson_06_dicts_loops_comprehensions/restoran_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Завантаження даних

# %%
import seaborn as sns



tips_dfm = sns.load_dataset("tips")
tips_dfm.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
print(len(tips_dfm))
# Out:
# 244

# %%
print(tips_dfm.columns)
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
from typing import NamedTuple

class Order(NamedTuple):
    total_bill: float
    tip: float
    sex: str
    smoker: str
    day: str
    time: str
    size: int

# %%
print(type(tips_dfm))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(tips_dfm.iterrows())
# Out:
# <generator object DataFrame.iterrows at 0x000002439DF0DC40>

# %%
next(tips_dfm.iterrows())
# Out:
# (0,
#  total_bill     16.99
#  tip             1.01
#  sex           Female
#  smoker            No
#  day              Sun
#  time          Dinner
#  size               2
#  Name: 0, dtype: object)

# %%
orders = []

for i, row in tips_dfm.iterrows():
    order = Order(
        total_bill = row["total_bill"],
        tip = row["tip"],
        sex= row["sex"],
        smoker= row["smoker"],
        day= row["day"],
        time= row["time"],
        size = row["size"]
    )
    orders.append(order)

print(orders[0])
# Out:
# Order(total_bill=16.99, tip=1.01, sex='Female', smoker='No', day='Sun', time='Dinner', size=2)

# %%
orders_2 = [
    Order(
        total_bill = row["total_bill"],
        tip = row["tip"],
        sex= row["sex"],
        smoker= row["smoker"],
        day= row["day"],
        time= row["time"],
        size = row["size"]
    )
for _, row in tips_dfm.iterrows()]

print(orders_2[0])
# Out:
# Order(total_bill=16.99, tip=1.01, sex='Female', smoker='No', day='Sun', time='Dinner', size=2)

# %%
for order in orders[:10]:
    tip_prc = (order.tip / order.total_bill) * 100
    print(tip_prc)
# Out:
# 5.9446733372572105
# 16.054158607350097
# 16.658733936220845
# 13.97804054054054
# 14.680764538430255
# 18.62396204033215
# 22.80501710376283
# 11.607142857142858
# 13.031914893617023
# 21.853856562922868

# %%
total_income = 0
total_tips = 0
total_guest = 0


for order in orders:
    total_income += order.total_bill
    total_tips += order.tip
    total_guest += order.size

avg_income = total_income / len(orders)

print(total_income)
print(avg_income)
print(total_tips)
print(total_guest)
# Out:
# 4827.770000000001
# 19.785942622950824
# 731.58
# 627

# %%
fruits = {
    "apple": 0,
    "banana": "green",
}

fruits["apple"] = fruits.get("apple", 0) + 4
print(fruits)
# Out:
# {'apple': 4, 'banana': 'green'}

# %%
income_day = {}
orders_day = {}
guest_day = {}

for order in orders:
    day = order.day
    income_day[day] = income_day.get(day, 0) + order.total_bill
    orders_day[day] = orders_day.get(day, 0) + 1
    guest_day[day] = guest_day.get(day, 0) + order.size



for day in income_day:
    n = orders_day[day]
    g = guest_day[day]
    r = income_day[day]
    print(f"{day}, {g}, {n}, {g/n:.1f} oсіб")
# Out:
# Sun, 216, 76, 2.8 oсіб
# Sat, 219, 87, 2.5 oсіб
# Thur, 152, 62, 2.5 oсіб
# Fri, 40, 19, 2.1 oсіб

# %%
big_orders = [order for order in orders if order.total_bill > 50]
print(len(big_orders))
print(big_orders)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 big_orders = [order for order in orders if order.total_bill > 50]
#       2 print(len(big_orders))
#       3 print(big_orders)
#
# NameError: name 'orders' is not defined

# %%
all_tip_percents = [(order.tip / order.total_bill) * 100 for order in orders]
print(all_tip_percents[0])
avg_tip = sum(all_tip_percents) / len(all_tip_percents)
print(f"середні {avg_tip:.2f}% min {min(all_tip_percents):.2f}% max {max(all_tip_percents):.2f}%")
# Out:
# 5.9446733372572105
# середні 16.08% min 3.56% max 71.03%

# %%
dinner_bills_1 = []

for order in orders:
    if order.time == "Dinner":
        dinner_bills_1.append(order.total_bill)

print(len(dinner_bills_1))
# Out:
# 176

# %%
dinner_bills = [order.total_bill for order in orders if order.time == 'Dinner']
print(len(dinner_bills))
# Out:
# 176

# %%
dinner_bills_1 = []

c=0

while c < len(orders):
    order = orders[c]
    if order.time == "Dinner":
        dinner_bills_1.append(order.total_bill)
    c += 1



print(len(dinner_bills_1))
# Out:
# 176
