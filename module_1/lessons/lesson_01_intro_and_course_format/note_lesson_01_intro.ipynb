# %% [markdown]
# <a href="https://colab.research.google.com/github/NikoriakViktot/PY-Course-Victor-Nikoriak-22-09-2026/blob/main/module_1/lessons/lesson_01_intro_and_course_format/note_lesson_01_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Урок 1 — Вступний урок: знайомство, формат курсу, AI-політика
#
# > **Мета уроку** — не код, а орієнтація: як влаштований курс, як ми працюємо з AI, і перше знайомство групи.

# %% [markdown]
# ## Що сьогодні
#
# Після цього заняття ти:
#
# - знатимеш, де матеріали курсу — книга і ноутбуки занять — і чим вони відрізняються;
# - розумітимеш два режими роботи з AI на курсі та коли який діє;
# - запустиш свою першу клітинку коду в Jupyter Notebook;
# - матимеш загальну картину, навіщо в курсі використовується Git/GitHub;
# - знатимеш, що підготувати до Уроку 2.
#
# Це організаційне заняття — жодного нового Python-синтаксису сьогодні не буде.

# %% [markdown]
# ## Формат курсу
#
# Матеріали курсу складаються з двох частин:
#
# ```text
# Курс
# │
# ├── 📖 книга (docs/)
# │     теорія, довідники, інструкції — Git, середовище, AI-політика
# │
# └── 📓 ноутбуки занять (module_N/lessons/lesson_NN_*/)
#       заняття "тут і зараз" — короткий контекст, приклад, вправа
#       + 📚 домашнє завдання в кінці того самого ноутбука
# ```
#
# - Ноутбук тримає лише те, що потрібно **саме зараз**: короткий контекст і завдання. Повний виклад теми — у книзі.
# - 👉 [`docs/index.md`](https://nikoriakviktot.github.io/PY-Course-Victor-Nikoriak-22-09-2026/) — з чого почати, як влаштована книга.
# - 👉 [`docs/00_getting_started/README.md`](https://nikoriakviktot.github.io/PY-Course-Victor-Nikoriak-22-09-2026/00_getting_started/) — усе організаційне: Git, GitHub, середовище, здача домашніх робіт, часті проблеми. Не переказуємо це тут — переходьте за посиланням, коли знадобиться.

# %% [markdown]
# ## Як влаштований Jupyter Notebook
#
# Цей файл, який ти зараз читаєш, — і є **notebook**: документ, що складається з окремих блоків — **cells** (клітинок).
#
# Є два типи клітинок:
#
# - **Markdown cell** — текст, як цей: пояснення, умови завдань, посилання. Не виконується, а лише форматується.
# - **Code cell** — Python-код. Виконується окремо від інших клітинок.
#
# Щоб виконати code cell:
#
# 1. Клікни всередину клітинки.
# 2. Натисни **Shift + Enter** (виконає клітинку і перейде до наступної) або **Ctrl + Enter** (виконає і залишиться на місці).
# 3. Результат (`Output`) з'явиться одразу під клітинкою.
#
# Клітинку можна запускати повторно й скільки завгодно разів: зміниш код і запустиш ще раз — старий Output заміниться новим.

# %% [markdown]
# ## 👋 Крок 0 — Познайомимось
#
# Це не система здачі завдань (вона ще не підключена в цьому репозиторії) — просто перша вправа, щоб застосувати щойно прочитане про клітинки.
#
# Поки не потрібно розуміти весь синтаксис нижче. Сьогодні наше завдання — змінити два значення і вперше запустити Python-код. Що таке змінні та `print()` детально, розберемо на Уроках 2–3.
#
# **Що зробити:**
#
# 1. Клікни всередину клітинки нижче.
# 2. Заміни обидва `"..."` на свій текст.
# 3. Натисни **Shift + Enter**.
# 4. Подивись на Output під клітинкою.

# %%
# Заповни своїми даними і запусти клітинку (Shift+Enter)

MY_NAME = "..."       # твоє ім'я
MY_GOAL = "..."        # одна причина, чому ти прийшов(-шла) на курс

print("Привіт! Мене звати", MY_NAME)
print("Моя мета на цьому курсі:", MY_GOAL)

# %% [markdown]
# ### 🔮 Спробуй ще раз
#
# 1. Зміни `MY_NAME` на інше значення (наприклад, вигадане ім'я) і запусти клітинку ще раз (Shift+Enter) — Output одразу оновиться.
# 2. Зміни `MY_GOAL` на щось інше — запусти ще раз.
# 3. Зверни увагу: код той самий, а Output щоразу новий, бо залежить від значень у змінних.
#
# Це і є базовий цикл роботи в notebook: **зміни код → запусти → подивись результат → зроби висновок.**

# %% [markdown]
# ## AI-політика курсу
#
# AI-асистент (Claude Code, Copilot, ChatGPT тощо) — це **співрозробник, а не заміна**. Курс визначає два режими роботи, і на кожному занятті буде зрозуміло, який саме зараз діє.
#
# ### Режим 1 — Самостійна перевірка (без AI)
#
# Коротке завдання без AI: пояснити код, знайти помилку. Мета — перевірити, що ти сам розумієш, що відбувається, без підказки.
#
# **Приклад:** на занятті викладач показує невеликий фрагмент коду з помилкою і просить усно пояснити, що станеться при запуску, — до того, як хтось його запустить.
#
# ### Режим 2 — Робота з AI (з перевіркою)
#
# Можна отримувати підказки й варіанти рішення від AI. Але результат проходить перевірку, а не приймається "на віру". Робочий цикл:
#
# ```text
# ASK → PREDICT → RUN → VERIFY → EXPLAIN → ADAPT
# ```
#
# 1. **Ask** — постав запитання чи попроси варіант рішення в AI.
# 2. **Predict** — перед тим як запускати, подумай, що має статися.
# 3. **Run** — запусти код.
# 4. **Verify** — перевір: результат збігається з прогнозом? Тести чи приклади проходять?
# 5. **Explain** — поясни своїми словами, що робить код рядок за рядком.
# 6. **Adapt** — зміни рішення під іншу вимогу (наприклад, викладач попросить змінити одну деталь — і ти маєш зрозуміти, що саме змінити).
#
# Якщо студент доходить до кроку Adapt і може змінити рішення сам(-а) — це і є доказ, що він(-она) реально зрозумів(-ла) код, а не просто скопіював(-ла) його.
#
# **Приклад:** ти просиш AI пояснити повідомлення про помилку — це нормально (Режим 2). Але вставити готовий код домашнього завдання без прогнозу результату — це саме той момент, де AI забирає в тебе навичку, яку урок мав розвинути.
#
# #### Корисне й некорисне використання AI
#
# | Ситуація | Корисне використання | Некорисне використання |
# |---|---|---|
# | Помилка (error) | «Поясни, що означає ця помилка» | «Зроби все завдання замість мене» |
# | Новий код | «Поясни цей рядок» | Сліпо вставити 40 рядків без прогнозу |
# | Домашня робота | Попросити натяк або альтернативний підхід | Здати AI-код, який не можеш пояснити |
#
# ### Примітка в домашніх роботах
#
# У кожному файлі, який здаєш, додавай рядок-коментар:
#
# ```python
# # AI log: одне речення — що саме питав у AI і що написав сам
# ```
#
# Якщо AI не використовував(-ла) — так і пиши:
#
# ```python
# # AI log: none
# ```
#
# Це не контроль заради покарання, а прозорість і рефлексія: рядок фіксує, що саме зробив AI, а що — ти сам(-а), і привчає усвідомлено користуватися AI як інструментом, а не як заміною власного мислення.
#
# Оцінюється і працездатність рішення, і здатність його пояснити — тому "готовий код без розуміння" не проходить перевірку навіть якщо він працює.
#
# > Ця політика діє в **усіх** модулях курсу, не лише в бонусному AI-треку (`Self-paced. AI для розробників`) наприкінці програми.

# %% [markdown]
# ### 🎯 Міні-сценарії — Режим 1 чи Режим 2?
#
# Для кожної ситуації подумай: це Режим 1 (без AI) чи Режим 2 (з AI, з перевіркою)?
#
# 1. Викладач показав 5 рядків коду й попросив усно передбачити результат — до запуску.
# 2. Ти отримав(-ла) незрозуміле повідомлення `TypeError: ...` і хочеш зрозуміти, що воно означає.
# 3. Потрібно придумати кілька різних способів розв'язати задачу з домашньої роботи.
# 4. Викладач попросив пояснити код власного домашнього рішення на занятті.
# 5. Ти вставив(-ла) рішення від AI в задачу, запустив(-ла) — і воно одразу спрацювало.
#
# *(Останній пункт — пастка: спрацювало ще не означає Verify → Explain → Adapt пройдено. Обговорюємо усно, жодна відповідь не здається окремо.)*

# %% [markdown]
# ## Git та GitHub — коротко
#
# Два різні поняття, які легко сплутати:
#
# ```text
# Git     = система керування історією змін (працює локально, на твоєму комп'ютері)
# GitHub  = сервіс, де живе віддалена копія репозиторію (для співпраці й здачі робіт)
# ```
#
# Ми працюємо через GitHub, як у реальній IT-команді:
#
# ```text
# репозиторій курсу → fork → clone → локальна робота → гілка → commit → push → Pull Request
# ```
#
# Pull Request (PR) = цільовий спосіб здачі домашньої роботи в цьому курсі.
#
# Повна інструкція вже написана — не дублюємо її тут:
#
# 👉 [`docs/00_getting_started/github/`](https://nikoriakviktot.github.io/PY-Course-Victor-Nikoriak-22-09-2026/00_getting_started/github/) — SSH-ключі, Fork і Clone, здача через PR.
#
# На цьому занятті достатньо розуміти цю модель; саме налаштування — до наступного заняття (Урок 2).

# %% [markdown]
# ## Самоперевірка — перевір себе
#
# Коротко, без AI (Режим 1 із цього ж уроку) дай усну або письмову відповідь:
#
# 1. Чим ноутбук заняття відрізняється від книги курсу — що йде куди?
# 2. Ти застряг(-ла) на помилці. Який запит до AI — це Режим 1, а який уже Режим 2: «поясни, що означає це повідомлення про помилку» чи «напиши мені робочий код»?
# 3. Ти скористався(-лась) підказкою AI в домашній роботі. Що саме має з'явитися в твоєму файлі?
# 4. Чому «код працює» — недостатня умова для зарахування завдання в цьому курсі?
# 5. Чим Git відрізняється від GitHub? Яким одним словом називається те, що ти відкриваєш, щоб здати домашню роботу?
#
# *(Відповіді не здаються окремо — це розминка перед першим реальним домашнім завданням на Уроці 2.)*

# %% [markdown]
# ## ✅ Перед Уроком 2
#
# - [ ] знаю, де книга курсу (`docs/index.md`) і де ноутбуки занять (`module_N/lessons/`)
# - [ ] розумію різницю між Режимом 1 і Режимом 2 роботи з AI
# - [ ] знаю, що результат від AI завжди перевіряється (`ASK → PREDICT → RUN → VERIFY → EXPLAIN → ADAPT`), а не приймається на віру
# - [ ] знаю про рядок `# AI log: ...` у кожному зданому файлі
# - [ ] запустив(-ла) свою першу code cell (Shift+Enter) і бачив(-ла) Output
# - [ ] знаю загальну модель Git/GitHub і що домашні роботи здаються через Pull Request
# - [ ] (за бажанням, необов'язково до Уроку 2) зазирнув(-ла) в [налаштування середовища](https://nikoriakviktot.github.io/PY-Course-Victor-Nikoriak-22-09-2026/00_getting_started/environment_setup/)

# %% [markdown]
# ## Далі
#
# Сьогодні ми навчилися орієнтуватися в курсі, запускати code cell і побачили модель роботи з AI та Git/GitHub.
#
# Урок 2 — [«Перші кроки та мінімальна робоча програма»](https://colab.research.google.com/github/NikoriakViktot/PY-Course-Victor-Nikoriak-22-09-2026/blob/main/module_1/lessons/lesson_02_first_steps_environment_setup/note_lesson_02_first_steps.ipynb): налаштуємо середовище (venv, ipykernel), розберемо, що насправді відбувається, коли Python виконує код (REPL vs скрипт), і розкладемо `print()` на деталі (`sep`, `end`, escape-послідовності) — перше домашнє завдання буде вже там.
