# %% [markdown]
# # Урок 1 — Вступний урок: знайомство, формат курсу, AI-політика
#
# > **Мета уроку** — не код, а орієнтація: як влаштований курс, як ми працюємо з AI, і перше знайомство групи.

# %% [markdown]
# ## Формат курсу
#
# Коротко (повна версія — у книзі документації курсу):
#
# - Заняття = ноутбуки (як цей) + книга теорії. Ноутбук тримає короткий контекст і завдання просто зараз; повний виклад — у книзі.
# - 👉 [`docs/index.md`](../../../docs/index.md) — з чого почати, як влаштована книга.
# - 👉 [`docs/00_getting_started/README.md`](../../../docs/00_getting_started/README.md) — усе організаційне: Git, GitHub, середовище, здача домашніх робіт, часті проблеми. Не переказуємо це тут — переходьте за посиланням, коли знадобиться.

# %% [markdown]
# ## AI-політика курсу
#
# AI-асистент (Claude Code, Copilot, ChatGPT тощо) — це **співрозробник, а не заміна**. Курс визначає два режими роботи, і на кожному занятті буде зрозуміло, який саме зараз діє.
#
# ### Режим 1 — Самостійна перевірка (без AI)
#
# Коротке завдання без AI: пояснити код, знайти помилку. Мета — перевірити, що ти сам розумієш, що відбувається, без підказки.
#
# **Приклад:** на занятті викладач показує невеликий фрагмент коду з помилкою і просить усно пояснити, що станеться при запуску, — до того, як хтось його запустить.
#
# ### Режим 2 — Робота з AI (з перевіркою)
#
# Можна отримувати підказки й варіанти рішення від AI. Але:
#
# - результат перевіряється тестами або запуском — не приймається "на віру";
# - ти можеш пояснити, що робить код рядок за рядком;
# - ти можеш адаптувати рішення під змінену вимогу (наприклад, викладач попросить змінити одну деталь — і ти маєш зрозуміти, що саме змінити).
#
# **Приклад:** ти просиш AI пояснити повідомлення про помилку — це нормально (Режим 2). Але вставити готовий код домашнього завдання без прогнозу результату — це саме той момент, де AI забирає в тебе навичку, яку урок мав розвинути.
#
# ### Примітка в домашніх роботах
#
# У кожному файлі, який здаєш, додавай рядок-коментар:
#
# ```python
# # AI log: одне речення — що саме питав у AI і що написав сам
# ```
#
# Якщо AI не використовував(-ла) — так і пиши:
#
# ```python
# # AI log: none
# ```
#
# Оцінюється і працездатність рішення, і здатність його пояснити — тому "готовий код без розуміння" не проходить перевірку навіть якщо він працює.
#
# > Ця політика діє в **усіх** модулях курсу, не лише в бонусному AI-треку (`Self-paced. AI для розробників`) наприкінці програми.

# %% [markdown]
# ## Git та GitHub — коротко
#
# Ми працюємо через GitHub, як у реальній IT-команді: fork → clone → гілка на кожну домашню роботу → Pull Request. Повна інструкція вже написана — не дублюємо її тут:
#
# 👉 [`docs/00_getting_started/github/`](../../../docs/00_getting_started/github/README.md) — SSH-ключі, Fork і Clone, здача через PR.
#
# На цьому занятті достатньо знати, що це існує; налаштування — до наступного заняття (Урок 2).

# %% [markdown]
# ## 👋 Крок 0 — Познайомимось
#
# Це не система здачі завдань (вона ще не підключена в цьому репозиторії) — просто перша вправа: заповни змінні нижче і запусти клітинку.

# %%
# Заповни своїми даними і запусти клітинку (Shift+Enter)

MY_NAME = "..."       # твоє ім'я
MY_GOAL = "..."        # одна причина, чому ти прийшов(-шла) на курс

print("Привіт! Мене звати", MY_NAME)
print("Моя мета на цьому курсі:", MY_GOAL)

# %% [markdown]
# ## Самоперевірка — AI-політика
#
# Коротко, без AI (Режим 1 із цього ж уроку) дай усну або письмову відповідь:
#
# 1. Ти застряг(-ла) на помилці. Який запит до AI — це Режим 1, а який уже Режим 2: «поясни, що означає це повідомлення про помилку» чи «напиши мені робочий код»?
# 2. Ти скористався(-лась) підказкою AI в домашній роботі. Що саме має з'явитися в твоєму файлі?
# 3. Чому «код працює» — недостатня умова для зарахування завдання в цьому курсі?
#
# *(Відповіді не здаються окремо — це розминка перед першим реальним домашнім завданням на Уроці 2.)*

# %% [markdown]
# ## Далі
#
# Урок 2 — [«Перші кроки та мінімальна робоча програма»](../lesson_02_first_steps_environment_setup/note_lesson_02_first_steps.ipynb): встановлюємо Python, запускаємо перший код, розбираємось із `print()`.
