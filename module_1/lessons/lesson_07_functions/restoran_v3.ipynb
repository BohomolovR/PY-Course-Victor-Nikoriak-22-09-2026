# %% [markdown]
# <a href="https://colab.research.google.com/github/NikoriakViktot/PY-Course-Victor-Nikoriak-22-09-2026/blob/main/module_1/lessons/lesson_07_functions/restoran_v3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from typing import NamedTuple



class Order(NamedTuple):
    total_bill: float
    tip: float
    sex: str
    smoker: str
    day: str
    time: str
    size: int

# %%
###
from typing import NamedTuple

class Order(NamedTuple):
    total_bill: float
    tip: float
    sex: str
    smoker: str
    day: str
    time: str
    size: int

##

import seaborn as sns

tips_df = sns.load_dataset("tips")
print(tips_df.head())

###

def orders_from_df(df) -> list[Order]:
    orders = []

    for _, row in df.iterrows():
        order = Order(
            total_bill=float(row["total_bill"]),
            tip=float(row["tip"]),
            sex=str(row["sex"]),
            smoker=str(row["smoker"]),
            day=str(row["day"]),
            time=str(row["time"]),
            size=int(row["size"]),
        )
        orders.append(order)

    return orders


orders = orders_from_df(tips_df)

print(len(orders))
print(orders[0])

####
dinner_orders = []
for order in orders:
    if    order.time == "Dinner":
        dinner_orders.append(order)
suma_chekov = 0
for order in dinner_orders:
    suma_chekov += order.total_bill
print("*"*50)
print(suma_chekov)
print(dinner_orders)

tip_percentages = []
kolichesto_chek = len(dinner_orders)
for order in dinner_orders:
    tip_percentages.append(round(order.tip / order.total_bill * 100))
print(tip_percentages)
print(kolichesto_chek)
x = (suma_chekov / kolichesto_chek)
print(x)
y = sum(tip_percentages)/ len(tip_percentages)
print(y)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 244
# Order(total_bill=16.99, tip=1.01, sex='Female', smoker='No', day='Sun', time='Dinner', size=2)
# **************************************************
# 3660.3000000000015
# ...

# %%
import seaborn as sns



tips_dfm = sns.load_dataset("tips")
print(tips_dfm.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
def  load_df(df):
    orders = [
    Order(
        total_bill = row["total_bill"],
        tip = row["tip"],
        sex= row["sex"],
        smoker= row["smoker"],
        day= row["day"],
        time= row["time"],
        size = row["size"]
    )
for _, row in df.iterrows()]
    return orders

# %%
orders = load_df(tips_dfm)

# %%
smoker_geust= []
for o in orders:
    if o.smoker == "Yes":\
        smoker_geust.append(o)
print(smoker_geust)
# Out:
# [Order(total_bill=38.01, tip=3.0, sex='Male', smoker='Yes', day='Sat', time='Dinner', size=4), Order(total_bill=11.24, tip=1.76, sex='Male', smoker='Yes', day='Sat', time='Dinner', size=2), Order(total_bill=20.29, tip=3.21, sex='Male', smoker='Yes', day='Sat', time='Dinner', size=2), Order(total_bill=13.81, tip=2.0, sex='Male', smoker='Yes', day='Sat', time='Dinner', size=2), Order(total_bill=11.02, tip=1.98, sex='Male', smoker='Yes', day='Sat', time='Dinner', size=2), Order(total_bill=18.29, tip=3.76, sex='Male', smoker='Yes', day='Sat', time='Dinner', size=4), Order(total_bill=3.07, tip=1.0, sex='Female', smoker='Yes', day='Sat', time='Dinner', size=1), Order(total_bill=15.01, tip=2.09, sex='Male', smoker='Yes', day='Sat', time='Dinner', size=2), Order(total_bill=26.86, tip=3.14, sex='Female', smoker='Yes', day='Sat', time='Dinner', size=2), Order(total_bill=25.28, tip=5.0, sex='Female', smoker='Yes', day='Sat', time='Dinner', size=2), Order(total_bill=17.92, tip=3.08, sex='Male', 
# ...

# %%
print(orders[1])
# Out:
# Order(total_bill=10.34, tip=1.66, sex='Male', smoker='No', day='Sun', time='Dinner', size=3)

# %%
def avg_bill(orders):
    if not orders:
        return 0.0
    total_bill = sum(o.total_bill for o in orders)
    print(total_bill)
    avg_bill = total_bill / len(orders)
    print(avg_bill)
    return avg_bill

# %%
sat_orders = [x for x in orders if x.day == "Sat"]
print(avg_bill(sat_orders))
# Out:
# 1778.3999999999996
# 20.441379310344825
# 20.441379310344825

# %%
sat_orders = [x for x in orders if x.time == "Dinner"]
print(avg_bill(sat_orders))
# Out:
# 3660.3000000000015
# 20.7971590909091
# 20.7971590909091

# %%
sat_orders = [x for x in orders if x.size >= 3]
print(avg_bill(sat_orders))
# Out:
# 2232.9100000000003
# 26.582261904761907
# 26.582261904761907
